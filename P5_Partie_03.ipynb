# %% [markdown]
# # Initiation à p5* version Python - Partie 3

# %% [markdown]
# ## Translations et rotations

# %% [markdown]
# Observez les 2 **transformations** ci-dessous, à savoir une **translation** puis une translation suivie d'une **rotation** :
#
# <img src="https://blog.univ-angers.fr/mathsinfo/files/2022/06/transRot.png">

# %% [markdown]
# 📌 Bien retenir que :
#
# - Les translations et rotations se définissent **avant** de dessiner les objets (rectangle, ligne, cercle...)
# - Vous pouvez **cumuler** les transformations
# - A chaque itération de `draw` le repère revient en haut à gauche

# %% [markdown]
# ## Exercice

# %% [markdown]
# Le programme ci-dessous est censé dessiner une étoile avec `n` traits alétoires, ce nombre étant choisi par l'utilisateur (entre 10 et 100).
#
# Comprenez-vous pourquoi lorsque `n = 10` (par exemple), il n'y a que 6 traits de visibles ?

# %%
from p5 import *
from random import randint

def setup():
    global angle, n
    createCanvas(800, 600) 
    frameRate(5)
    background(210)
    angleMode(DEGREES)
    n = 0
    while not(n >= 10 and n <= 100):
        n = int(input('Entrez un nombre entre 10 et 100 : '))
    angle = 360 / n   

def draw():
    translate(width / 2, height / 2)
    for i in range(n):
        rotate(i * angle)
        line(0, 0, randint(0,300), 0)
    noLoop()
    
run()
# Out:
# Entrez un nombre entre 10 et 100 : 10

# %% [markdown]
# ## Sauvegarde avec push et pop

# %% [markdown]
# Le problème du programme précédent est que les **rotations se cumulent**. Par exemple avec `n = 10` (`angle = 36`) on commence par une rotation de 0° puis de 1 $\times$ 36°, ensuite on ajoute une rotation de 2 $\times$ 36 = 72° soit 108°. Puis ajout de $3\times 36 = 108$° soit 216° ensuite 216° + 4 $\times$ 36° = 360° etc. Vous pourrez vérifier que l'on obtient uniquement les angles : 0°, 36°, 108°, 180°, 216° et 288°.

# %% [markdown]
# On voudrait qu'à chaque tour dans la boucle `for` la rotation précédente ne soit pas prise en compte. Pour cela, avant d'appeler `rotate`, on va **sauvegarder** la transformation précédent en utilisant `push`. On **récupèrera** ensuite la configuration avec `pop`. C'est le principe des **piles**.

# %%
from p5 import *
from random import randint

def setup():
    global angle, n
    createCanvas(800, 600) 
    frameRate(5)
    background(210)
    angleMode(DEGREES)
    n = 0
    while not(n >= 10 and n <= 100):
        n = int(input('Entrez un nombre entre 10 et 100 : '))
    angle = 360 / n   

def draw():
    translate(width / 2, height / 2)
    for i in range(n):
        push()                           # On sauvegarde la configuration précédente
        rotate(i * angle)
        line(0, 0, randint(0,300), 0)
        pop()                            # puis on la récupère
    noLoop()
    
run()
# Out:
# Entrez un nombre entre 10 et 100 : 10

# %% [markdown]
# 📌 Rappelons qu'à chaque appel de `draw` les transformations sont remises à zéro, cela peut être un moyen d'éviter les cumuls.

# %% [markdown]
# ## Exercice - les insectes

# %% [markdown]
# <div class = "alert alert-block alert-warning">
# Le but de l'exercice est de créer une planche de 10 $\times$ 10 = 100 insectes (visuel ci-desous). Chaque insecte est constitué de 10 traits :
#
# - partant d'un même centre (0, 0)
# - de directions aléatoires entre 0° et 360°
# - d'épaisseurs (`strokeWeight`) aléatoires entre 1 et 4
# - de longueurs aléatoires entre 2 et 10 px
#
# <img src="https://blog.univ-angers.fr/mathsinfo/files/2022/06/insectes.png">
#
# - Créez une fonction `insecte` qui dessine un insecte à la position `(0, 0)`
# - A l'aide de `translate`, `push` et `pop`, créez la planche d'insectes.</div>

# %%
from p5 import *
from random import randint

def insecte():
    for _ in range(10):
        strokeWeight(randint(1, 4))
        line(0, 0, randint(2, 10), 0)
        rotate(randint(0, 360))
        
def setup():
    angleMode(DEGREES)
    createCanvas(400, 400)
    
def draw():
    translate(10,10)
    for i in range(100):
        push()
        translate(40 * (i % 10) , 40 * (i // 10))
        insecte()
        pop()
    noLoop()
    
run()

# %% [markdown]
# ## Epicycloïdes et hypocycloïdes

# %% [markdown]
# 😵‍💫 Que ces 2 mots barbares ne fassent pas peur aux plus littéraires, nous n'allons pas faire de calculs compliqués mais juste de transformations simples (translations et rotations) !

# %% [markdown]
# Observons cet **épicyloïde** tirée du site <a href="https://mathcurve.com/courbes2d/epicycloid/epicycloid.shtml" target="_blank">mathcurve.com</a> :
#
# <img src="https://blog.univ-angers.fr/mathsinfo/files/2022/06/epicycloid1.gif">
#
# Un cercle **extérieur** (ici le petit en noir) roule sans glisser **autour** d'un cercle **intérieur** (le grand en bleu). On s'intéresse à la **figure dessinée en rouge** qui est la trajectoire de l'**extrémité du rayon** du cercle extérieur.
#
# Essayez de vous convaincre que si le **centre du cercle extérieur** tourne à **vitesse constante**, plus le rayon du cercle extérieur sera **petit**, plus le rayon extérieur **tournera vite**.
#
# On admettra que si le rayon du cercle extérieur est `n` fois plus petit que celui du cercle intérieur, la vitesse de rotation du rayon sera `n` fois plus grande. Par exemple, si le rayon du cercle noir est 5 fois plus petit que le rayon du cercle bleu, le petit rayon tournera 5 fois plus vite que le centre du petit cercle.

# %% [markdown]
# ### Exercice

# %% [markdown]
# Ecrire un premier programme qui à chaque tour de `draw` :
#
# - Efface l'écran
# - Place l'origine au milieu de la fenêtre (400 x 400)
# - Effectue une rotation constante (on pourra utiliser `frameCount` qui est une variable système permettant de **connaitre le nombre de tours** (d'images) que l'on a déjà affichés). Par exemple, si vous êtes en degrés, `frameCount * 2` effectuera une rotation de 2° au premier tour puis une rotation de 4° au second tour, 6° au troisième, etc.
# - Tracez un trait de longueur 100
# - Tracez un cercle de diamètre 200 (mettre `noFill()` dans le `setup()` pour ne pas avoir de remplissage).

# %%
from p5 import *

def setup():
    createCanvas(400,400)
    angleMode(DEGREES)
    noFill()

def draw():
    background(255, 255, 255)
    translate(width / 2, height / 2)
    rotate(frameCount * 2)
    line(0,0, 100 , 0)
    circle(0,0,200)
    if mouseIsPressed:
        noLoop()

run()

# %%
stop()

# %% [markdown]
# <div class = "alert alert-block alert-warning">
# Améliorations de votre programme :
#
#
# - On veut dessiner un cercle extérieur qui aura comme rayon 50 (la moitié du cercle intérieur). Pour cela prolongez le rayon jusqu'à 100 + 50 = 150.
# - Faire une translation pour vous amener au centre du petit cercle
# - Effectuez une rotation 2 fois plus rapide du grand cercle (par exemple 4° par tour si le grand cercle fait à 2° par tour)
# - Dessinez un trait de longueur 50 (rayon du petit cercle)
# - Dessinez le petit cercle de diamètre 100
#
# Vous devriez obtenir quelque chose comme :
#
# <img src="https://blog.univ-angers.fr/mathsinfo/files/2022/06/2cercles.png"></div>

# %%
from p5 import *
from random import randint,random

def setup():
    global q
    createCanvas(400, 400)
    angleMode(DEGREES)
    noFill()

def draw():
    background(255, 255, 255)
    translate(width/2, height/2)
    rotate(frameCount * 2)
    line(0, 0, 150, 0)
    circle(0, 0, 200)
    translate(150, 0)
    rotate(frameCount * 4)
    line(0, 0, 50, 0)
    circle(0, 0, 100 )
    if mouseIsPressed:
        noLoop()

run()

# %% [markdown]
# Nouvelles améliorations :
#
# - Demandez à l'utilisateur d'entrer un nombre `n` décimal (`float`) entre 2 et 20
# - Le rayon du petit cercle doit être égale à `100 / n`. Donc le premier rayon qui part du centre aura comme longueur `100 + 100 / n`
# - La vitesse du petit cercle sera `n` fois plus rapide que celle du grand cercle (`frameCount * n`)
# - Effectuez une nouvelle translation pour vous mettre à l'extrémité du rayon du cercle extérieur
# - Ajoutez un gros point rouge (`stroke` pour définir la couleur, `strokeWeight` pour son épaisseur et `point(x, y)` pour dessiner le point)

# %%
from p5 import *
from random import randint,random

def setup():
    global n
    createCanvas(400, 400)
    angleMode(DEGREES)
    n = float(input('Entrez un nombre entre 2 et 20 : '))
    noFill()

def draw():
    background(255, 255, 255)
    stroke(200)
    strokeWeight(2)
    translate(width/2, height/2)
    rotate(frameCount * 2)
    rayon = 100 + 100 / n
    line(0, 0, rayon, 0)
    circle(0, 0, 200)
    translate(rayon, 0)
    rotate(frameCount * 2 * n)
    rayon2 = 100 / n
    line(0, 0, rayon2, 0)
    circle(0, 0, 2 * rayon2)
    translate(rayon2, 0)
    stroke('red')
    strokeWeight(6)
    point(0, 0)
    if mouseIsPressed:
        noLoop()

run()
# Out:
# Entrez un nombre entre 2 et 20 : 5

# %% [markdown]
# Mettre en commentaires les lignes adéquates pour voir uniquement la trajectoire du point rouge.

# %%
from p5 import *
from random import randint

def setup():
    global n
    createCanvas(400,400)
    angleMode(DEGREES)
    n = float(input('Entrez un nombre entre 2 et 20 : '))
    noFill()

def draw():
    #background(255, 255, 255)
    #stroke(200)
    #strokeWeight(2)
    translate(width/2, height/2)
    rotate(frameCount * 2)
    rayon = 100 + 100 / n
    #line(0,0, rayon, 0)
    #circle(0,0, 200)
    translate(rayon, 0)
    rotate(frameCount * 2 * n)
    rayon2 = 100 / n
    #line(0,0, rayon2, 0)
    #circle(0,0, 2 * rayon2)
    translate(rayon2, 0)
    stroke('red')
    strokeWeight(6)
    point(0, 0)
    if mouseIsPressed:
        noLoop()

run()
# Out:
# Entrez un nombre entre 2 et 20 : 5

# %% [markdown]
# Observez attentivement (sur le site <a href="https://mathcurve.com/courbes2d/hypocycloid/hypocycloid.shtml" target="_blank">mathcurve.com</a>) la différence entre les **épiclycoïdes** et les **hypocycloïdes**. Repérez les **positions des cercles** et les **sens de rotation**.
#
# Modifiez le programme précédent pour qu'il dessine des hypocycloïdes (il y a uniquement **2 choses à changer** !).

# %%
from p5 import *
from random import randint

def setup():
    global n
    createCanvas(400,400)
    angleMode(DEGREES)
    n = float(input('Entrez un nombre entre 2 et 20 : '))
    noFill()

def draw():
    #background(255, 255, 255)
    #stroke(200)
    #strokeWeight(2)
    translate(width/2, height/2)
    rotate(frameCount * 2)
    rayon = 100 - 100 / n
    #line(0,0, rayon, 0)
    #circle(0,0, 200)
    translate(rayon, 0)
    rotate(- frameCount * 2 * n)
    rayon2 = 100 / n
    #line(0,0, rayon2, 0)
    #circle(0,0, 2 * rayon2)
    translate(rayon2, 0)
    stroke('red')
    strokeWeight(6)
    point(0, 0)
    if mouseIsPressed:
        noLoop()

run()
# Out:
# Entrez un nombre entre 2 et 20 : 2.6
